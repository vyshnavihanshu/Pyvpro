# %%
from signal import valid_signals


class Student:
    total_number_of_students = 10
    shared_passing_marks = 35
    def __init__(self,name,marks):
        self.name=name
        self.marks=marks
    def check (self):
        if Student.shared_passing_marks>self.marks:
             return "passed"
        else:
             return "failed"
    @classmethod
    def change_marks(cls,marks):
        cls.percentage=(marks/Student.total_number_of_students)*100
    @staticmethod
    def utility(x):
         if  x>40 and 60>x:
             print("A")
         elif x>60 and 80>x:
             print("B")
         elif x>80 and 100>x:
             print("c")
s1 = Student("Kiya",60)
s2 = Student("Riya",75)
# student=[s1,s2]
# for s in student:
#     print(s.name,s.marks,s.check(),Student.utility(s.marks))
print(s1.name,s1.marks,s1.check(),Student.utility(s1.marks))
print(s2.name,s2.marks,s2.check(),Student.utility(s2.marks))

Student.change_marks(15)
print(s1.name,s1.marks,s1.check(),Student.utility(s1.marks))
print(s2.name,s2.marks,s2.check(),Student.utility(s2.marks))
# Out:
# Kiya 60 failed None
# B
# Riya 75 failed None
# Kiya 60 failed None
# B
# Riya 75 failed None
# Kiya 60 failed None
# B
# Riya 75 failed None
# Kiya 60 failed None
# B
# Riya 75 failed None

# %%
class Product:
    tax_rate=11
    def __init__(self,name,baseprice):
        self.name = name
        self.baseprice = baseprice
    def final_price(self):
         print(price=self.baseprice+(self.baseprice)*Product.tax_rate/100)
    @classmethod
    def change_tax_rate(cls,new_tax_rate):
        cls.tax_rate=new_tax_rate
    @staticmethod
    def check(baseprice):
        if baseprice>0:
            return "valid"
        return "Invalid valid"
p1=Product("Kiya",100)
p2=Product("Riya",60)

p1.change_tax_rate(100)
p2.change_tax_rate(100)

print(Product.check(-12))
# Out:
# not valid
